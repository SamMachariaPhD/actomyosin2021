# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("ggplot")
cm = 1/2.54
import glob

# %%
f0_0l = glob.glob('data/tip/TipXYF0.0*.txt')
f0_25l = glob.glob('data/tip/TipXYF0.25*.txt')
f0_5l = glob.glob('data/tip/TipXYF0.5*.txt')
f1_0l = glob.glob('data/tip/TipXYF1.0**.txt')
f1_5l = glob.glob('data/tip/TipXYF1.5**.txt')
f_0_25l = glob.glob('data/tip/TipXYF-0.25**.txt')
f_0_5l = glob.glob('data/tip/TipXYF-0.5**.txt')
f_1_0l = glob.glob('data/tip/TipXYF-1.0**.txt')

# %%
f0_0 = []
for i in f0_0l:
    _ = pd.read_csv(i, names=['t','x','y'], delim_whitespace=True)
    f0_0.append(_)

f0_25 = []
for i in f0_25l:
    _ = pd.read_csv(i, names=['t','x','y'], delim_whitespace=True)
    f0_25.append(_)

f0_5 = []
for i in f0_5l:
    _ = pd.read_csv(i, names=['t','x','y'], delim_whitespace=True)
    f0_5.append(_)
    
f1_0 = []
for j in f1_0l:
    _ = pd.read_csv(j, names=['t','x','y'], delim_whitespace=True)
    f1_0.append(_)    
    
f1_5 = []
for k in f1_5l:
    _ = pd.read_csv(k, names=['t','x','y'], delim_whitespace=True)
    f1_5.append(_)
    
f_0_5 = []
for l in f_0_5l:
    _ = pd.read_csv(l, names=['t','x','y'], delim_whitespace=True)
    f_0_5.append(_)
    
f_0_25 = []
for i in f_0_25l:
    _ = pd.read_csv(i, names=['t','x','y'], delim_whitespace=True)
    f_0_25.append(_)
    
f_1_0 = []
for m in f_1_0l:
    _ = pd.read_csv(m, names=['t','x','y'], delim_whitespace=True)
    f_1_0.append(_)

# %%
fig, ax = plt.subplots(2,3, figsize=(12,6), sharex=True, sharey=True, constrained_layout=True)
fig.subplots_adjust(hspace=-0.5)
fig.subplots_adjust(wspace=0.05)
#plt.subplot_tool()

for i in range(4):
    ax[0,2].plot(f_1_0[i]['x'],f_1_0[i]['y'],lw=1)
    ax[0,2].set_aspect('equal')
    ax[0,2].minorticks_on()
    ax[0,2].tick_params(which='both',direction='in', top=True, right=True)
    #ax[0,2].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[0,0].set_ylabel('Y ($\mu m$)', fontsize=16)
    ax[0,2].set_title('$F = -1.0\ pN/\mu m$', fontsize=16)
    
for i in range(4):
    ax[0,1].plot(f_0_5[i]['x'],f_0_5[i]['y'],lw=1)
    ax[0,1].set_aspect('equal')
    ax[0,1].minorticks_on()
    ax[0,1].tick_params(which='both', direction='in', top=True, right=True)
    #ax[0,1].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[0,1].set_title('$F = -0.5\ pN/\mu m$', fontsize=16)
    
for i in range(4):
    ax[0,0].plot(f_0_25[i]['x'],f_0_25[i]['y'],lw=1)
    ax[0,0].set_aspect('equal')
    ax[0,0].minorticks_on()
    ax[0,0].tick_params(which='both', direction='in', top=True, right=True)
    #ax[0,0].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[0,0].set_title('$F = -0.25\ pN/\mu m$', fontsize=16)
        
# for i in range(4):
#     ax[1,1].plot(f0_0[i]['x'],f0_0[i]['y'],lw=1)
#     ax[1,1].set_aspect('equal')
#     ax[1,1].minorticks_on()
#     ax[1,1].tick_params(which='both', direction='in', top=True, right=True)
#     #ax[1,1].set_xlabel('X ($\mu m$)', fontsize=16)
#     ax[1,1].set_title('$F = 0.0\ pN/\mu m$', fontsize=16)
    
for i in range(4):
    ax[1,0].plot(f0_25[i]['x'],f0_25[i]['y'],lw=1)
    ax[1,0].set_aspect('equal')
    ax[1,0].minorticks_on()
    ax[1,0].tick_params(which='both', direction='in', top=True, right=True)
    #ax[1,0].set_ylabel('Y ($\mu m$)', fontsize=16)
    ax[1,0].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[1,0].set_title('$F = 0.25\ pN/\mu m$', fontsize=16)
    
for i in range(4):
    ax[1,1].plot(f0_5[i]['x'],f0_5[i]['y'],lw=1)
    ax[1,1].set_aspect('equal')
    ax[1,1].minorticks_on()
    ax[1,1].tick_params(which='both', direction='in', top=True, right=True)
    ax[1,1].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[1,1].set_title('$F = 0.5\ pN/\mu m$', fontsize=16)
    
for i in range(4):
    ax[1,2].plot(f1_0[i]['x'],f1_0[i]['y'],lw=1)
    ax[1,2].set_aspect('equal')
    ax[1,2].minorticks_on()
    ax[1,2].tick_params(which='both', direction='in',top=True, right=True)
    ax[1,2].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[1,0].set_ylabel('Y ($\mu m$)', fontsize=16)
    ax[1,2].set_title('$F = 1.0\ pN/\mu m$', fontsize=16)
    
# for i in range(4):
#     ax[1,3].plot(f1_5[i]['x'],f1_5[i]['y'],lw=1)
#     ax[1,3].set_aspect('equal')
#     ax[1,3].minorticks_on()
#     ax[1,3].tick_params(which='both', direction='in', top=True, right=True)
#     ax[1,3].set_xlabel('X ($\mu m$)', fontsize=16)
#     ax[1,3].set_title('$F = 1.5\ pN/\mu m$', fontsize=16)

#plt.tight_layout()

#plt.savefig('fig/pulling_fieldF-1to1.pdf', format='pdf', bbox_inches='tight')
plt.show()
# Out:
# /home/nitta/.local/lib/python3.5/site-packages/matplotlib/figure.py:2144: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   warnings.warn("This figure was using constrained_layout==True, "

# %%
fig, ax = plt.subplots(1,1, figsize=(10*cm,10*cm), sharex=True, sharey=True, constrained_layout=True)
#fig.subplots_adjust(hspace=-0.5)
#fig.subplots_adjust(wspace=0.05)

for i in range(4):
    ax.plot(f0_0[i]['x'],f0_0[i]['y'],lw=1)
    ax.set_aspect('equal')
    ax.minorticks_on()
    ax.tick_params(which='both', direction='in', top=True, right=True)
    ax.set_xlabel('X ($\mu m$)', fontsize=16)
    ax.set_ylabel('Y ($\mu m$)', fontsize=16)
    ax.set_title('$F = 0.0\ pN/\mu m$', fontsize=16)

#plt.savefig('fig/pulling_fieldF0.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1,4, figsize=(40*cm,10*cm), sharex=True, sharey=True, constrained_layout=True)
fig.subplots_adjust(hspace=-0.5)
fig.subplots_adjust(wspace=0.05)
#plt.subplot_tool()

for i in range(4):
    ax[0].plot(f0_0[i]['x'],f0_0[i]['y'],lw=1)
    ax[0].set_aspect('equal')
    ax[0].minorticks_on()
    ax[0].tick_params(which='both', direction='in', top=True, right=True)
    ax[0].set_ylabel('Y ($\mu m$)', fontsize=16)
    ax[0].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[0].set_title('$F = 0.0\ pN/\mu m$', fontsize=16)
    ax[0].set_xticks(np.arange(-25,26,5))
    ax[0].set_yticks(np.arange(-5,16,5)) 
    
for i in range(4):
    ax[1].plot(f_0_25[i]['x'],f_0_25[i]['y'],lw=1)
    ax[1].set_aspect('equal')
    ax[1].minorticks_on()
    ax[1].tick_params(which='both', direction='in', top=True, right=True)
    ax[1].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[1].set_title('$F = -0.25\ pN/\mu m$', fontsize=16)
    
for i in range(4):
    ax[2].plot(f_0_5[i]['x'],f_0_5[i]['y'],lw=1)
    ax[2].set_aspect('equal')
    ax[2].minorticks_on()
    ax[2].tick_params(which='both', direction='in', top=True, right=True)
    ax[2].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[2].set_title('$F = -0.5\ pN/\mu m$', fontsize=16)
        
for i in range(4):
    ax[3].plot(f_1_0[i]['x'],f_1_0[i]['y'],lw=1)
    ax[3].set_aspect('equal')
    ax[3].minorticks_on()
    ax[3].tick_params(which='both',direction='in', top=True, right=True)
    ax[3].set_xlabel('X ($\mu m$)', fontsize=16)
    #ax[3].set_ylabel('Y ($\mu m$)', fontsize=16)
    ax[3].set_title('$F = -1.0\ pN/\mu m$', fontsize=16)
    

#plt.tight_layout()

#plt.savefig('fig/pulling_fieldFminus.pdf', format='pdf', bbox_inches='tight')
#plt.savefig('fig/pulling_fieldFminus.png', format='png', bbox_inches='tight', dpi=200)
#plt.savefig('fig/pulling_fieldFminus.svg', format='svg', bbox_inches='tight')

plt.show()

# %%
import subprocess

subprocess.call('inkscape fig/pulling_fieldFminus.svg -M fig/pulling_fieldFminus.emf',shell=True)
# Out:
# 0

# %%
fig, ax = plt.subplots(1,4, figsize=(40*cm,10*cm), sharex=True, sharey=True, constrained_layout=True)
fig.subplots_adjust(hspace=-0.5)
fig.subplots_adjust(wspace=0.05)
#plt.subplot_tool()

for i in range(4):
    ax[0].plot(f0_0[i]['x'],f0_0[i]['y'],lw=1)
    ax[0].set_aspect('equal')
    ax[0].minorticks_on()
    ax[0].tick_params(which='both', direction='in', top=True, right=True)
    ax[0].set_ylabel('Y ($\mu m$)', fontsize=16)
    ax[0].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[0].set_title('$F = 0.0\ pN/\mu m$', fontsize=16)
    ax[0].set_xticks(np.arange(-0,26,5))
    ax[0].set_yticks(np.arange(-5,16,5))    
    
for i in range(4):
    ax[1].plot(f0_25[i]['x'],f_0_25[i]['y'],lw=1)
    ax[1].set_aspect('equal')
    ax[1].minorticks_on()
    ax[1].tick_params(which='both', direction='in', top=True, right=True)
    ax[1].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[1].set_title('$F = 0.25\ pN/\mu m$', fontsize=16)
    
for i in range(4):
    ax[2].plot(f0_5[i]['x'],f_0_5[i]['y'],lw=1)
    ax[2].set_aspect('equal')
    ax[2].minorticks_on()
    ax[2].tick_params(which='both', direction='in', top=True, right=True)
    ax[2].set_xlabel('X ($\mu m$)', fontsize=16)
    ax[2].set_title('$F = 0.5\ pN/\mu m$', fontsize=16)
        
for i in range(4):
    ax[3].plot(f1_0[i]['x'],f_1_0[i]['y'],lw=1)
    ax[3].set_aspect('equal')
    ax[3].minorticks_on()
    ax[3].tick_params(which='both',direction='in', top=True, right=True)
    ax[3].set_xlabel('X ($\mu m$)', fontsize=16)
    #ax[3].set_ylabel('Y ($\mu m$)', fontsize=16)
    ax[3].set_title('$F = 1.0\ pN/\mu m$', fontsize=16)


#plt.tight_layout()

#plt.savefig('fig/pulling_fieldFplus.pdf', format='pdf', bbox_inches='tight')
#plt.savefig('fig/pulling_fieldFplus.png', format='png', bbox_inches='tight', dpi=200)
#plt.savefig('fig/pulling_fieldFplus.svg', format='svg', bbox_inches='tight')

plt.show()

# %%
import subprocess

subprocess.call('inkscape fig/pulling_fieldFplus.svg -M fig/pulling_fieldFplus.emf',shell=True)
# Out:
# 0

# %%
F = np.array([0.00,0.25,0.50,1.00])
f0xmax = np.array([f0_0[0]['x'].max(), f0_0[1]['x'].max(), f0_0[2]['x'].max(), f0_0[3]['x'].max()])
f0xmn = f0xmax.mean()
f0xstd = f0xmax.std()
f25xmax = np.array([f0_25[0]['x'].max(), f0_25[1]['x'].max(), f0_25[2]['x'].max(), f0_25[3]['x'].max()])
f25xmn = f25xmax.mean()
f25xstd = f25xmax.std()
f5xmax = np.array([f0_5[0]['x'].max(), f0_5[1]['x'].max(), f0_5[2]['x'].max(), f0_5[3]['x'].max()])
f5xmn = f5xmax.mean()
f5xstd = f5xmax.std()
f1xmax = np.array([f1_0[0]['x'].max(), f1_0[1]['x'].max(), f1_0[2]['x'].max(), f1_0[3]['x'].max()])
f1xmn = f1xmax.mean()
f1xstd = f1xmax.std()

fxmn = np.array([f0xmn,f25xmn,f5xmn,f1xmn])
fxstd = np.array([f0xstd,f25xstd,f5xstd,f1xstd])

#====================================================

F_ = np.array([-0.00,-0.25,-0.50,-1.00])
f_0xmax = np.array([f0_0[0]['x'].min(), f0_0[1]['x'].min(), f0_0[2]['x'].min(), f0_0[3]['x'].max()])
f_0xmn = f_0xmax.mean()
f_0xstd = f_0xmax.std()
f_25xmax = np.array([f_0_25[0]['x'].min(), f_0_25[1]['x'].min(), f_0_25[2]['x'].min(), f_0_25[3]['x'].min()])
f_25xmn = f_25xmax.mean()
f_25xstd = f_25xmax.std()
f_5xmax = np.array([f_0_5[0]['x'].min(), f_0_5[1]['x'].min(), f_0_5[2]['x'].min(), f_0_5[3]['x'].min()])
f_5xmn = f_5xmax.mean()
f_5xstd = f_5xmax.std()
f_1xmax = np.array([f_1_0[0]['x'].min(), f_1_0[1]['x'].min(), f_1_0[2]['x'].min(), f_1_0[3]['x'].min()])
f_1xmn = f_1xmax.mean()
f_1xstd = f_1xmax.std()

f_xmn = np.array([f_0xmn,f_25xmn,f_5xmn,f_1xmn])
f_xstd = np.array([f_0xstd,f_25xstd,f_5xstd,f_1xstd])

# %%
fig, ax = plt.subplots(1,2, figsize=(20*cm,10*cm))

ax[0].errorbar(F_,f_xmn,f_xstd, color='brown', markerfacecolor='sandybrown', marker="o", ls="--",\
            lw=1, elinewidth=2, capsize=2)

ax[0].set_xlabel('Force (pN)', fontsize=16)
ax[0].set_ylabel('X-distance ($\mu m$)', fontsize=16)
#ax[0].set_xticks(np.arange(-0,-1.1,-0.25))
#ax[0].set_yticks(np.arange(-20,10,5))
ax[0].minorticks_on()
ax[0].tick_params(direction='in', length=8, width=0.5, which='major', labelsize=12)
ax[0].tick_params(direction='in', length=3, width=0.5, which='minor', labelsize=12)

#----------------------------

ax[1].errorbar(F,fxmn,fxstd, color='brown', markerfacecolor='sandybrown', marker="o", ls="--",\
            lw=1, elinewidth=2, capsize=2)

ax[1].set_xlabel('Force (pN)', fontsize=16)
#ax[1].set_ylabel('X-distance ($\mu m$)', fontsize=16)
ax[1].set_xticks(np.arange(0,1.1,0.25))
ax[1].set_yticks(np.arange(5,30.1,5))
ax[1].minorticks_on()
ax[1].tick_params(direction='in', length=8, width=0.5, which='major', labelsize=12)
ax[1].tick_params(direction='in', length=3, width=0.5, which='minor', labelsize=12)

#plt.savefig('fig/force-field-dist.pdf', format='pdf', bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(1,1, figsize=(10*cm,10*cm))

ax.errorbar(F,fxmn,fxstd, color='brown', markerfacecolor='sandybrown', marker="o", ls="--",\
            lw=1, elinewidth=2, capsize=2)

ax.set_xlabel('Force (pN)', fontsize=16)
ax.set_ylabel('X-distance ($\mu m$)', fontsize=16)
ax.set_xticks(np.arange(0,1.1,0.25))
ax.set_yticks(np.arange(5,30.1,5))
ax.minorticks_on()
ax.tick_params(direction='in', length=8, width=0.5, which='major', labelsize=12)
ax.tick_params(direction='in', length=3, width=0.5, which='minor', labelsize=12)

#plt.savefig('fig/force-field-dist_v2.pdf', format='pdf', bbox_inches='tight')
#plt.savefig('fig/force-field-dist_v2.svg', format='svg', bbox_inches='tight')
plt.show()

# %%
import subprocess

subprocess.call('inkscape fig/force-field-dist_v2.svg -M fig/force-field-dist_v2.emf',shell=True)
# Out:
# 0

# %%
ydiff0 = np.array([np.diff(f0_0[0]['y']).mean(), np.diff(f0_0[1]['y']).mean(), np.diff(f0_0[2]['y']).mean(), np.diff(f0_0[3]['y']).mean()])
xdiff0 = np.array([np.diff(f0_0[0]['x']).mean(), np.diff(f0_0[1]['x']).mean(), np.diff(f0_0[2]['x']).mean(), np.diff(f0_0[3]['x']).mean()])

# %%
ydiff0
# Out:
# array([ 0.05219641,  0.01048647, -0.01727612,  0.02278923])

# %%
xdiff0
# Out:
# array([ 0.03295881, -0.01440623,  0.04847754, -0.00869407])

# %%
ydiff1 = np.array([np.diff(f1_0[0]['y']).mean(), np.diff(f1_0[1]['y']).mean(), np.diff(f1_0[2]['y']).mean(), np.diff(f1_0[3]['y']).mean()])
xdiff1 = np.array([np.diff(f1_0[0]['x']).mean(), np.diff(f1_0[1]['x']).mean(), np.diff(f1_0[2]['x']).mean(), np.diff(f1_0[3]['x']).mean()])

# %%
ydiff1
# Out:
# array([ 0.00029882, -0.00469537,  0.00241714, -0.00023047])

# %%
xdiff1
# Out:
# array([0.07506847, 0.0765231 , 0.07679998, 0.07679208])

# %%
f0_0[0]['y'], f0_0[3]['y']
# Out:
# (0       0.000000
#  1       0.070700
#  2      -0.005317
#  3       0.122581
#  4       0.072821
#           ...
#  296    15.365394
#  297    15.457037
#  298    15.512203
#  299    15.584297
#  300    15.658923
#  Name: y, Length: 301, dtype: float64,
#  0      0.000000
#  1     -0.069944
#  2     -0.136008
#  3     -0.134075
#  4     -0.086511
#           ...
#  296    7.183350
#  297    7.036660
#  298    7.052185
#  299    6.969424
#  300    6.836769
#  Name: y, Length: 301, dtype: float64)

# %%
np.diff(f1_0[0]['y']).mean(), np.diff(f1_0[3]['y']).mean()
# Out:
# (0.00029882000000000037, -0.00023046666666666734)

# %%
plt.plot( np.diff(f0_0[3]['y']) )

# %%
np.arccos(1/1)
# Out:
# 0.0

# %%
x0d = np.diff(f0_0[0]['x'])
y0d = np.diff(f0_0[0]['y'])

# %%
np.arccos(x0d[0]/(np.sqrt(x0d[0]**2+y0d[0]**2)))
# Out:
# 1.0477245576136698

# %%
np.arccos(x0d[299]/(np.sqrt(x0d[299]**2+y0d[299]**2)))
# Out:
# 1.5034153040148344

# %%
x0d = np.diff(f1_0[0]['x'])
y0d = np.diff(f1_0[0]['y'])

# %%
np.arccos(x0d[0]/(np.sqrt(x0d[0]**2+y0d[0]**2)))
# Out:
# 0.4162369435828991

# %%
np.arccos(x0d[299]/(np.sqrt(x0d[299]**2+y0d[299]**2)))
# Out:
# 1.3466854147192042
