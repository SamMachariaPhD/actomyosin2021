# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use("ggplot")
cm = 1/2.54

# %matplotlib inline
#import seaborn as sns

# %%
mdn = np.array([500,1000,1500,2000,2500,3000,3500,4000,4500]) 

sn = pd.read_csv('data/v11N_MDspd_std273s5.csv', names=['spd','std'])

# %%
fig, ax = plt.subplots(figsize=(20*cm,15*cm))
#plt.style.use('ggplot') # like R figures *
#from pylab import *; rc('axes', linewidth=1)

ax.errorbar(mdn,sn['spd'],sn['std'], marker='o', mec='black', linestyle='--', lw=1, color='brown',\
            ecolor='grey', elinewidth=3, capsize=3, markerfacecolor='lightblue')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
#ax.spines['right'].set_color('none')
#ax.spines['top'].set_color('none')
#ax.spines['bottom'].set_position(('axes',-0.01))
#ax.spines['left'].set_position(('axes',-0.01))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

#ax.set_xticks(np.arange(0,5001,step=1000))
#ax.set_yticks(np.arange(2,13,2))

#ax.spines['left'].set_bounds(2,12)

ax.minorticks_on()
ax.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

ax.set_xlabel('Myosin density', fontsize=16)
ax.set_ylabel('Speed ($\mu m/s$)', fontsize=16)
#ax.legend(loc='lower right')

fig.tight_layout()
#plt.savefig('fig/MotorDensityChangesn.svg', fmt='svg', dip='1000', bbox_inches='tight')
#plt.savefig('fig/MotorDensityChangesV11n.png', format='png', dpi=700, bbox_inches='tight')

#plt.savefig('fig/MotorDensityChangesV11n.pdf', format='pdf', dpi=500, bbox_inches='tight')

plt.show()

# %%
# !jupyter nbconvert ChangingMD_v11n.ipynb --no-input --to html
# Out:
# [NbConvertApp] Converting notebook ChangingMD_v11n.ipynb to html
# [NbConvertApp] Writing 588996 bytes to ChangingMD_v11n.html
