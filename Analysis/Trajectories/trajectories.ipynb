# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
conf = pd.read_csv('data/Conformation_R08_213_5s_F9.2pN.txt', names=['time','x','y','z'], delim_whitespace=True)

dt = 0.01; dt002 = 0.02; dt005 = 0.05; dt01 = 0.1; dt02 = 0.2; dt05 = 0.5; dt1 = 1; dt2 = 2; dt5 = 5
x = np.array([0.01,0.02,0.05,0.1,0.2,0.5,1.0,2.0,5.0])

# %%
#============================================================================
Head = conf.iloc[0::13,:]
Head = Head.reset_index(drop=True)
#============================================================================
Head002 = Head.iloc[0::2,:]
Head002 = Head002.reset_index(drop=True)
#============================================================================
Head005 = Head.iloc[0::5,:]
Head005 = Head005.reset_index(drop=True)
#============================================================================
Head01 = Head.iloc[0::10,:]
Head01 = Head01.reset_index(drop=True)
#============================================================================
Head02 = Head.iloc[0::20,:]
Head02 = Head02.reset_index(drop=True)
#============================================================================
Head05 = Head.iloc[0::50,:]
Head05 = Head05.reset_index(drop=True)
#============================================================================
Head1 = Head.iloc[0::100,:]
Head1 = Head1.reset_index(drop=True)
#============================================================================
Head2 = Head.iloc[0::200,:]
Head2 = Head2.reset_index(drop=True)
#============================================================================
Head5 = Head.iloc[0::500,:]
Head5 = Head5.reset_index(drop=True)
#============================================================================

#============================================================================
dxHead = np.diff(Head['x'])
dyHead = np.diff(Head['y'])
#============================================================================
dxHead002 = np.diff(Head002['x'])
dyHead002 = np.diff(Head002['y'])
#============================================================================
dxHead005 = np.diff(Head005['x'])
dyHead005 = np.diff(Head005['y'])
#============================================================================
dxHead01 = np.diff(Head01['x'])
dyHead01 = np.diff(Head01['y'])
#============================================================================
dxHead02 = np.diff(Head02['x'])
dyHead02 = np.diff(Head02['y'])
#============================================================================
dxHead05 = np.diff(Head05['x'])
dyHead05 = np.diff(Head05['y'])
#============================================================================
dxHead1 = np.diff(Head1['x'])
dyHead1 = np.diff(Head1['y'])
#============================================================================
dxHead2 = np.diff(Head2['x'])
dyHead2 = np.diff(Head2['y'])
#============================================================================
dxHead5 = np.diff(Head5['x'])
dyHead5 = np.diff(Head5['y'])
#============================================================================

#============================================================================
distHead = np.sqrt((dxHead**2)+(dyHead**2))#; np.savetxt('R1F5pN_distHead001.txt',distHead,fmt='%.8f',delimiter = '\t')
spdHead = distHead/(1*dt)
avSpdHead = np.mean(spdHead)
#============================================================================
distHead002 = np.sqrt((dxHead002**2)+(dyHead002**2))#; np.savetxt('R1F5pN_distHead002.txt',distHead002,fmt='%.8f',delimiter = '\t')
spdHead002 = distHead002/(2*dt)
avSpdHead002 = np.mean(spdHead002)
#============================================================================
distHead005 = np.sqrt((dxHead005**2)+(dyHead005**2))#; np.savetxt('R1F5pN_distHead005.txt',distHead005,fmt='%.8f',delimiter = '\t')
spdHead005 = distHead005/(5*dt)
avSpdHead005 = np.mean(spdHead005)
#============================================================================
distHead01 = np.sqrt((dxHead01**2)+(dyHead01**2))#; np.savetxt('R1F5pN_distHead01.txt',distHead01,fmt='%.8f',delimiter = '\t')
spdHead01 = distHead01/(10*dt)
avSpdHead01 = np.mean(spdHead01)
#============================================================================
distHead02 = np.sqrt((dxHead02**2)+(dyHead02**2))#; np.savetxt('R1F5pN_distHead02.txt',distHead02,fmt='%.8f',delimiter = '\t')
spdHead02 = distHead02/(20*dt)
avSpdHead02 = np.mean(spdHead02)
#============================================================================
distHead05 = np.sqrt((dxHead05**2)+(dyHead05**2))#; np.savetxt('R1F5pN_distHead05.txt',distHead05,fmt='%.8f',delimiter = '\t')
spdHead05 = distHead05/(50*dt)
avSpdHead05 = np.mean(spdHead05)
#============================================================================
distHead1 = np.sqrt((dxHead1**2)+(dyHead1**2))#; np.savetxt('R1F5pN_distHead1.txt',distHead1,fmt='%.8f',delimiter = '\t')
spdHead1 = distHead1/(100*dt)
avSpdHead1 = np.mean(spdHead1)
#============================================================================
distHead2 = np.sqrt((dxHead2**2)+(dyHead2**2))#; np.savetxt('R1F5pN_distHead2.txt',distHead2,fmt='%.8f',delimiter = '\t')
spdHead2 = distHead2/(200*dt)
avSpdHead2 = np.mean(spdHead2)
#============================================================================
distHead5 = np.sqrt((dxHead5**2)+(dyHead5**2))#; np.savetxt('R1F5pN_distHead5.txt',distHead5,fmt='%.8f',delimiter = '\t')
spdHead5 = distHead5/(500*dt)
avSpdHead5 = np.mean(spdHead5)
#============================================================================
avSpdH = np.array([avSpdHead,avSpdHead002,avSpdHead005,avSpdHead01,avSpdHead02,avSpdHead05,avSpdHead1,avSpdHead2,avSpdHead5])

#============================================================================
stdHead = np.sum(((spdHead-avSpdHead)**2)/(np.size(spdHead)-1))
stdHead = np.sqrt(stdHead)
#============================================================================
stdHead002 = np.sum(((spdHead002-avSpdHead002)**2)/(np.size(spdHead002)-1))
stdHead002 = np.sqrt(stdHead002)
#============================================================================
stdHead005 = np.sum(((spdHead005-avSpdHead005)**2)/(np.size(spdHead005)-1))
stdHead005 = np.sqrt(stdHead005)
#============================================================================
stdHead01 = np.sum(((spdHead01-avSpdHead01)**2)/(np.size(spdHead01)-1))
stdHead01 = np.sqrt(stdHead01)
#============================================================================
stdHead02 = np.sum(((spdHead02-avSpdHead02)**2)/(np.size(spdHead02)-1))
stdHead02 = np.sqrt(stdHead02)
#============================================================================
stdHead05 = np.sum(((spdHead05-avSpdHead05)**2)/(np.size(spdHead05)-1))
stdHead05 = np.sqrt(stdHead05)
#============================================================================
stdHead1 = np.sum(((spdHead1-avSpdHead1)**2)/(np.size(spdHead1)-1))
stdHead1 = np.sqrt(stdHead1)
#============================================================================
stdHead2 = np.sum(((spdHead2-avSpdHead2)**2)/(np.size(spdHead2)-1))
stdHead2 = np.sqrt(stdHead2)
#============================================================================
stdHead5 = np.sum(((spdHead5-avSpdHead5)**2)/(np.size(spdHead5)-1))
stdHead5 = np.sqrt(stdHead5)
#============================================================================
stdH = np.array([stdHead,stdHead002,stdHead005,stdHead01,stdHead02,stdHead05,stdHead1,stdHead2,stdHead5])

#============================================================================
xHead = np.arange(0,spdHead.shape[0])
xHead01 = np.arange(0,spdHead.shape[0], step=10)
#============================================================================
# Out:
# /home/nitta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:123: RuntimeWarning: invalid value encountered in true_divide

# %%
fig, ax = plt.subplots(figsize=(10,8))
#plt.style.use('ggplot') # like R figures *

#plt.figure(figsize=(16,8))
#plt.axes().set_aspect('equal','datalim')
#plt.suptitle('R = 1.0, $F_{M2}$ = 9.2pN')

ax.set_title('R = 0.8, $F_{M2}$ = 9.2 pN', fontsize=16)

#plt.subplot(2,5,1)
ax.hist(distHead, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='blue', label='$\Delta t$ = 0.01')

#plt.subplot(2,5,2)
ax.hist(distHead002, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='green', label='$\Delta t$ = 0.02')

#plt.subplot(2,5,3)
ax.hist(distHead005, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='red', label='$\Delta t$ = 0.05')

#plt.subplot(2,5,4)
ax.hist(distHead01, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='magenta', label='$\Delta t$ = 0.1')

#plt.subplot(2,5,5)
ax.hist(distHead02, bins=np.arange(0,2,0.02), histtype='bar',ec='black',color='purple', label='$\Delta t$ = 0.2')

#plt.subplot(2,5,6)
ax.hist(distHead05, bins=np.arange(0,5,0.02), histtype='bar',ec='black',color='pink', label='$\Delta t$ = 0.5')


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
#ax.spines['right'].set_color('none')
#ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('axes',-0.01))
ax.spines['left'].set_position(('axes',-0.01))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(np.arange(0.0,7,step=2))
ax.set_yticks(np.arange(0,401,100))
#ax.set_ylim(ymin=0)

ax.tick_params(labelsize=18, direction='out', length=6, width=1) # colors='r', grid_color='r', grid_alpha=0.5
ax.set_xlabel('Length between trajectory points ($\mu m$)', fontsize=18)
ax.set_ylabel('Number of occurences', fontsize=18)
ax.legend(loc='upper left')

ax.legend()

#plt.savefig('fig/v9trajHistR08F9pNall.png', fmt='png', dpi=1000, bbox_inches='tight')
#plt.savefig('fig/v9trajHistR08F9pNall.svg', fmt='svg', dpi=1000, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,12))
ax.set_aspect('equal')

ax.plot(Head['x'], Head['y'],linestyle='--',marker='.',color='red', label='$\Delta t$ = 0.01')
ax.plot(Head002['x'], Head002['y'],linestyle='--',marker='.',color='yellow', label='$\Delta t$ = 0.02')
ax.plot(Head005['x'], Head005['y'],linestyle='--',marker='.',color='purple', label='$\Delta t$ = 0.05')
ax.plot(Head01['x'], Head01['y'],linestyle='--',marker='.',color='magenta', label='$\Delta t$ = 0.1')
ax.plot(Head02['x'], Head02['y'],linestyle='--',marker='.',color='green', label='$\Delta t$ = 0.2')
ax.plot(Head05['x'], Head05['y'],linestyle='--',marker='.',color='blue', label='$\Delta t$ = 0.5')
ax.plot(Head1['x'], Head1['y'],linestyle='--',marker='.',color='black', label='$\Delta t$ = 1.0')
ax.plot(Head2['x'], Head2['y'],linestyle='--',marker='.',color='pink', label='$\Delta t$ = 2.0')
ax.plot(Head5['x'], Head5['y'],linestyle='--',marker='.',color='grey', label='$\Delta t$ = 5.0')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

#ax.set_yticks(np.arange(0,11,2))
#ax.set_xticks(np.arange(0.2,1.21,0.2))
ax.tick_params(labelsize=18)

ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)

ax.legend()

#plt.savefig('fig/v9RvsSpd.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9XYtrajF9.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
#fig, ax = plt.subplots(figsize=(15,12))
#ax.set_aspect('equal')

plt.figure(figsize=(15,6))
plt.axes().set_aspect('equal','datalim')

plt.subplot(2,5,1)
plt.plot(Head['x'], Head['y'],linestyle='--',marker='.',color='red', label='$\Delta t$ = 0.01')
plt.legend()
plt.subplot(2,5,2)
plt.plot(Head002['x'], Head002['y'],linestyle='--',marker='.',color='black', label='$\Delta t$ = 0.02')
plt.legend()
plt.subplot(2,5,3)
plt.plot(Head005['x'], Head005['y'],linestyle='--',marker='.',color='purple', label='$\Delta t$ = 0.05')
plt.legend()
plt.subplot(2,5,4)
plt.plot(Head01['x'], Head01['y'],linestyle='--',marker='.',color='magenta', label='$\Delta t$ = 0.1')
plt.legend()
plt.subplot(2,5,5)
plt.plot(Head02['x'], Head02['y'],linestyle='--',marker='.',color='green', label='$\Delta t$ = 0.2')
plt.legend()
plt.subplot(2,5,6)
plt.plot(Head05['x'], Head05['y'],linestyle='--',marker='.',color='blue', label='$\Delta t$ = 0.5')
plt.legend()
plt.subplot(2,5,7)
plt.plot(Head1['x'], Head1['y'],linestyle='--',marker='.',color='yellow', label='$\Delta t$ = 1.0')
plt.legend()
plt.subplot(2,5,8)
plt.plot(Head2['x'], Head2['y'],linestyle='--',marker='.',color='pink', label='$\Delta t$ = 2.0')
plt.legend()
plt.subplot(2,5,9)
plt.plot(Head5['x'], Head5['y'],linestyle='--',marker='.',color='grey', label='$\Delta t$ = 5.0')
plt.legend()
#ax.spines['right'].set_visible(False)
#ax.spines['top'].set_visible(False)

#ax.set_yticks(np.arange(0,11,2))
#ax.set_xticks(np.arange(0.2,1.21,0.2))
#ax.tick_params(labelsize=18)

#ax.set_xlabel('X', fontsize=18)
#ax.set_ylabel('Y', fontsize=18)

#plt.savefig('fig/v9RvsSpd.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9XYtrajGF9.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(15,12))
ax.set_aspect('equal')

#ax.plot(Head['x'], Head['y'],linestyle='--',marker='.',color='red', label='$\Delta t$ = 0.01')
#ax.plot(Head002['x'], Head002['y'],linestyle='--',marker='.',color='black', label='$\Delta t$ = 0.02')
#ax.plot(Head005['x'], Head005['y'],linestyle='--',marker='.',color='purple', label='$\Delta t$ = 0.05')
#ax.plot(Head01['x'], Head01['y'],linestyle='--',marker='.',color='magenta', label='$\Delta t$ = 0.1')
ax.plot(Head02['x'], Head02['y'],linestyle='--',marker='.',color='green', label='$\Delta t$ = 0.2')
#ax.plot(Head05['x'], Head05['y'],linestyle='--',marker='.',color='blue', label='$\Delta t$ = 0.5')
#ax.plot(Head1['x'], Head1['y'],linestyle='--',marker='.',color='black', label='$\Delta t$ = 1.0')
#ax.plot(Head2['x'], Head2['y'],linestyle='--',marker='.',color='pink', label='$\Delta t$ = 2.0')
#ax.plot(Head5['x'], Head5['y'],linestyle='--',marker='.',color='grey', label='$\Delta t$ = 5.0')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)

#ax.set_yticks(np.arange(0,11,2))
#ax.set_xticks(np.arange(0.2,1.21,0.2))
ax.tick_params(labelsize=18)

ax.set_xlabel('X', fontsize=18)
ax.set_ylabel('Y', fontsize=18)

ax.legend()

#plt.savefig('fig/v9RvsSpd.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9XYtrajF9_02.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
plt.figure(figsize=(15,6))
plt.axes().set_aspect('equal','datalim')
plt.suptitle('R = 1.0, $F_{M2}$ = 9.2pN')

plt.subplot(2,5,1)
#num_bins = [0,0.2]
#n, bins, patches = plt.hist(distHead, num_bins, facecolor='blue', alpha=0.5)
#plt.hist(distHead,bins=20,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')
#plt.yticks(np.arange(0.0,26,2.0))
#

#bins = [0, 0.02]
#hist, bin_edges = np.histogram(distHead)#, bins=bins)

plt.hist(distHead, bins=np.arange(0,1,0.02),ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')
plt.legend()

plt.subplot(2,5,2)
plt.hist(distHead002,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.02')
plt.yticks(np.arange(0.0,26,2.0))
plt.legend()

plt.subplot(2,5,3)
plt.hist(distHead005,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.05')
plt.yticks(np.arange(0.0,26,2.0))
plt.legend()

plt.subplot(2,5,4)
plt.hist(distHead01,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.1')
plt.yticks(np.arange(0.0,26,2.0))
plt.legend()

plt.subplot(2,5,5)
plt.hist(distHead02,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.2')
plt.yticks(np.arange(0.0,26,2.0))
plt.legend()

plt.subplot(2,5,6)
plt.hist(distHead05,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.5')
plt.yticks(np.arange(0.0,26,2.0))
plt.legend()

plt.subplot(2,5,7)
plt.hist(distHead1,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 1')
plt.yticks(np.arange(0.0,26,2.0))
plt.legend()

plt.subplot(2,5,8)
plt.hist(distHead2,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 2')
plt.yticks(np.arange(0.0,62,6.0))
plt.legend()

plt.subplot(2,5,9)
plt.hist(distHead5,bins=20,density=True,ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 3')
plt.yticks(np.arange(0.0,26,2.0))
plt.legend()

#plt.savefig('fig/v9RvsSpd.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9trajHistF9pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
plt.figure(figsize=(15,6))
#plt.axes().set_aspect('equal','datalim')
plt.suptitle('R = 0.3, $F_{M2}$ = 5 pN')


#plt.hist(distHead, bins=np.arange(0,4,0.02),ec='black',histtype='bar',color='green', label='$\Delta t$ = 0.01')

#plt.hist(distHead002, bins=np.arange(0,1,0.02),ec='black',histtype='bar',color='blue', label='$\Delta t$ = 0.01')

#plt.hist(distHead005, bins=np.arange(0,1,0.02),ec='black',histtype='bar',color='red', label='$\Delta t$ = 0.01')

#plt.hist(distHead01, bins=np.arange(0,1,0.02),ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')

#plt.hist(distHead02, bins=np.arange(0,1,0.02),ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')

#plt.hist(distHead05, bins=np.arange(0,4,1),ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')
#binwidth = 0.02
#plt.hist(distHead05, bins=np.arange(min(distHead05), max(distHead05) + binwidth, binwidth))




plt.subplot(2,5,1)
plt.hist(distHead, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='blue')

plt.subplot(2,5,2)
plt.hist(distHead002, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='green')

plt.subplot(2,5,3)
plt.hist(distHead005, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='red')

plt.subplot(2,5,4)
plt.hist(distHead01, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='magenta')

plt.subplot(2,5,5)
plt.hist(distHead02, bins=np.arange(0,2,0.02), histtype='bar',ec='black',color='green')

plt.subplot(2,5,6)
plt.hist(distHead05, bins=np.arange(0,5,0.02), histtype='bar',ec='black',color='green')







#plt.hist(distHead1, bins=np.arange(0,2,0.02),ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')

#plt.hist(distHead2, bins=np.arange(0,1,0.02),ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')

#plt.hist(distHead5, bins=np.arange(0,40,5),ec='black',histtype='bar',alpha=0.75,color='green', label='$\Delta t$ = 0.01')


#plt.savefig('fig/v9RvsSpd.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9trajHistF5pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
#plt.style.use('ggplot') # like R figures *

#plt.figure(figsize=(16,8))
#plt.axes().set_aspect('equal','datalim')
#plt.suptitle('R = 1.0, $F_{M2}$ = 9.2pN')

ax.set_title('R = 0.8, $F_{M2}$ = 10 pN', fontsize=16)

#plt.subplot(2,5,1)
ax.hist(distHead, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='blue', label='$\Delta t$ = 0.01')

#plt.subplot(2,5,2)
ax.hist(distHead002, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='green', label='$\Delta t$ = 0.02')

#plt.subplot(2,5,3)
ax.hist(distHead005, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='red', label='$\Delta t$ = 0.05')

#plt.subplot(2,5,4)
ax.hist(distHead01, bins=np.arange(0,1,0.02), histtype='bar',ec='black',color='magenta', label='$\Delta t$ = 0.1')

#plt.subplot(2,5,5)
ax.hist(distHead02, bins=np.arange(0,2,0.02), histtype='bar',ec='black',color='purple', label='$\Delta t$ = 0.2')

#plt.subplot(2,5,6)
ax.hist(distHead05, bins=np.arange(0,5,0.02), histtype='bar',ec='black',color='pink', label='$\Delta t$ = 0.5')


ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
#ax.spines['right'].set_color('none')
#ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('axes',-0.01))
ax.spines['left'].set_position(('axes',-0.01))

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_xticks(np.arange(0.0,7,step=2))
ax.set_yticks(np.arange(0,501,100))
#ax.set_ylim(ymin=0)

ax.tick_params(labelsize=18, direction='out', length=6, width=1) # colors='r', grid_color='r', grid_alpha=0.5
ax.set_xlabel('Length between trajectory points ($\mu m$)', fontsize=18)
ax.set_ylabel('Number of occurences', fontsize=18)
ax.legend(loc='upper left')

ax.legend()

#plt.savefig('fig/v9trajHistR08F10pNall.png', fmt='png', dpi=1000, bbox_inches='tight')
#plt.savefig('fig/v9trajHistR08F10pNall.svg', fmt='svg', dpi=1000, bbox_inches='tight')

plt.show()

# %%
# new harddisk HDCZ-UT FM2 = 9.2 pN

columns = ['t', 'x', 'y']
tip = []

for t in np.arange(0.1,1.1, step=0.1):
    #print(round(t,1))
    tipXY = pd.read_csv('data/TipXY'+str(round(t,1))+'seed213F9.2.txt', names=columns, delim_whitespace=True)
    tip001 = tipXY.drop(['t'], axis=1) # dt = 0.01*1 = 0.01 sec
    tip01 = tip001.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1
    tip.append(tip001)
#tip = np.array([tip])

# %%
# new harddisk HDCZ-UT FM2 = 9.2 pN

columns = ['t', 'x', 'y']
Tip = []

for t in np.arange(0.1,1.1, step=0.1):
    #print(round(t,1))
    tipXY = pd.read_csv('data/TipXY'+str(round(t,1))+'seed113s5.txt', names=columns, delim_whitespace=True)
    tip001 = tipXY.drop(['t'], axis=1) # dt = 0.01*1 = 0.01 sec
    tip01 = tip001.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1
    Tip.append(tip001)
#tip = np.array([tip])

# %%
# dt = 0.01 modified
plt.figure(figsize=(4*3.19,4*1.94)) #20,12

from pylab import *
rc('axes', linewidth=2)

#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]', fontsize=18)
#plt.suptitle('Figure 1: Representative shuttle trajectories', y=-0.0001, fontsize=18)
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.25)
plt.axes().set_aspect(aspect = 'equal', adjustable='box')

r = 0.5

for p in range(4,10):
    plt.subplot(2,3,p-3)
    #print(p)
    plt.plot(tip[p]['x'],tip[p]['y'], label='Leading tip', color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
    plt.xticks(np.arange(-5,41,step=10),fontsize=16)
    plt.yticks(np.arange(-20,26,step=10),fontsize=16)
    plt.title('Ratio = '+str(round(r,1)), fontsize=18)
    if p == 4 or p == 7:
        plt.ylabel('Y ($\mu m$)', fontsize=17)
    if p >= 7:
        plt.xlabel('X ($\mu m$)', fontsize=17)
    r += 0.1
#plt.savefig('fig/v9allTrajF9pN.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9allTrajF9pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
# dt = 0.01 modified
plt.figure(figsize=(4*3.19,4*1.94)) #20,12

from pylab import *
rc('axes', linewidth=1)

#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]', fontsize=18)
#plt.suptitle('Figure 1: Representative shuttle trajectories', y=-0.0001, fontsize=18)
plt.subplots_adjust(wspace=0.3)
plt.subplots_adjust(hspace=0.25)
plt.axes().set_aspect(aspect = 'equal', adjustable='box')

r = 0.5

for p in range(4,10):
    plt.subplot(2,3,p-3)
    #print(p)
    plt.plot(Tip[p]['x'],Tip[p]['y'], label='Leading tip', color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
    plt.xticks(np.arange(-5,41,step=10),fontsize=16)
    plt.yticks(np.arange(-20,26,step=10),fontsize=16)
    plt.title('Ratio = '+str(round(r,1)), fontsize=18)
    if p == 4 or p == 7:
        plt.ylabel('Y ($\mu m$)', fontsize=17)
    if p >= 7:
        plt.xlabel('X ($\mu m$)', fontsize=17)
    r += 0.1
plt.savefig('fig/v9allTrajF9pNPsta.png', fmt='png', dpi=1500, bbox_inches='tight')
#plt.savefig('fig/v9allTrajF9pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
# new harddisk HDCZ-UT FM2 = 8 pN

columns = ['t', 'x', 'y']
tip10 = []

for t in np.arange(0.1,1.1, step=0.1):
    #print(round(t,1))
    tipXY = pd.read_csv('data/TipXY'+str(round(t,1))+'seed213F10.txt', names=columns, delim_whitespace=True)
    tip001 = tipXY.drop(['t'], axis=1) # dt = 0.01*1 = 0.01 sec
    tip01 = tip001.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1
    tip10.append(tip001)
#tip = np.array([tip])

# %%
# dt = 0.01 modified
plt.figure(figsize=(15,5.5))
#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]', fontsize=18)
#plt.suptitle('Figure 1: Representative shuttle trajectories', y=-0.0001, fontsize=18)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect(aspect = 'equal', adjustable='box')

r = 0.1

for p in range(0,10):
    plt.subplot(2,5,p+1)
    plt.plot(tip10[p]['x'],tip10[p]['y'], label='Leading tip', color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
    plt.xticks(np.arange(-5,41,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('Ratio = '+str(round(r,1)), fontsize=16)
    if p == 0 or p == 5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if p >= 5:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    r += 0.1
#plt.savefig('fig/v9allTrajF10pN.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9allTrajF10pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
columns = ['t', 'x', 'y']
tip8 = []

for t in np.arange(0.1,1.1, step=0.1):
    #print(round(t,1))
    tipXY = pd.read_csv('data/TipXY'+str(round(t,1))+'seed213F8.txt', names=columns, delim_whitespace=True)
    tip001 = tipXY.drop(['t'], axis=1) # dt = 0.01*1 = 0.01 sec
    tip01 = tip001.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1
    tip8.append(tip001)

# %%
plt.figure(figsize=(15,5.5))
#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]', fontsize=18)
#plt.suptitle('Figure 1: Representative shuttle trajectories', y=-0.0001, fontsize=18)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect(aspect = 'equal', adjustable='box')

r = 0.1

for p in range(0,10):
    plt.subplot(2,5,p+1)
    plt.plot(tip8[p]['x'],tip8[p]['y'], label='Leading tip', color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
    plt.xticks(np.arange(-5,41,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('Ratio = '+str(round(r,1)), fontsize=16)
    if p == 0 or p == 5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if p >= 5:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    r += 0.1
#plt.savefig('fig/v9allTrajF8pN.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9allTrajF8pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
columns = ['t', 'x', 'y']
tip6 = []

for t in np.arange(0.1,1.1, step=0.1):
    tipXY = pd.read_csv('data/TipXY'+str(round(t,1))+'seed213F6.txt', names=columns, delim_whitespace=True)
    tip001 = tipXY.drop(['t'], axis=1) # dt = 0.01*1 = 0.01 sec
    tip01 = tip001.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1
    tip6.append(tip001)

# %%
plt.figure(figsize=(15,5.5))
#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]', fontsize=18)
#plt.suptitle('Figure 1: Representative shuttle trajectories', y=-0.0001, fontsize=18)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect(aspect = 'equal', adjustable='box')

r = 0.1

for p in range(0,10):
    plt.subplot(2,5,p+1)
    plt.plot(tip6[p]['x'],tip6[p]['y'], label='Leading tip', color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
    plt.xticks(np.arange(-5,41,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('Ratio = '+str(round(r,1)), fontsize=16)
    if p == 0 or p == 5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if p >= 5:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    r += 0.1
#plt.savefig('fig/v9allTrajF6pN.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9allTrajF6pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')

# %%
columns = ['t', 'x', 'y']
tip5 = []

for t in np.arange(0.1,1.1, step=0.1):
    tipXY = pd.read_csv('data/TipXY'+str(round(t,1))+'seed213F5.txt', names=columns, delim_whitespace=True)
    tip001 = tipXY.drop(['t'], axis=1) # dt = 0.01*1 = 0.01 sec
    tip01 = tip001.iloc[0::10, :] #pick every 9th row starting from the first. Here dt = 0.01*10 = 0.1
    tip5.append(tip001)

# %%
plt.figure(figsize=(15,5.5))
#plt.axis('tight')
#plt.suptitle('Actin Filament Grinding Trajectory [dt = 0.01]', fontsize=18)
#plt.suptitle('Figure 1: Representative shuttle trajectories', y=-0.0001, fontsize=18)
plt.subplots_adjust(wspace=0.4)
plt.subplots_adjust(hspace=0.4)
plt.axes().set_aspect(aspect = 'equal', adjustable='box')

r = 0.1

for p in range(0,10):
    plt.subplot(2,5,p+1)
    plt.plot(tip5[p]['x'],tip5[p]['y'], label='Leading tip', color='black', marker='.', linestyle='-', linewidth=0.5, markersize=1)
    plt.xticks(np.arange(-5,41,step=10),fontsize=14)
    plt.yticks(np.arange(-20,26,step=10),fontsize=14)
    plt.title('Ratio = '+str(round(r,1)), fontsize=16)
    if p == 0 or p == 5:
        plt.ylabel('Y ($\mu m$)', fontsize=16)
    if p >= 5:
        plt.xlabel('X ($\mu m$)', fontsize=16)
    r += 0.1
#plt.savefig('fig/v9allTrajF5pN.png', fmt='png', dpi=500, bbox_inches='tight')
#plt.savefig('fig/v9allTrajF5pN.svg', fmt='svg', dpi=3000, bbox_inches='tight')
