# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
beads = 13
beads2 = 2
dt = 0.01
dt01 = 0.1
cm = 1/2.54

# %%
#defF = 4.6 pN, actF = 9.2 pN, R = 0.5, B = 13, ATP = 2000, MD = 3000, S = 77, T = 5
conf = pd.read_csv('data/Conformation_A001.txt', names=['time','x','y','z'], delim_whitespace=True)
bmAc = pd.read_csv('data/bmAc.csv', names=['bm'])
bminAc = pd.read_csv('data/bminAc.csv', names=['bm'])
#defF = 9.2 pN, actF = 9.2 pN, R = 0.92, B = 13, ATP = 2000, MD = 3000, S = 77, T = 5
conf9 = pd.read_csv('data/R090/Conformation_A001.txt', names=['time','x','y','z'], delim_whitespace=True)
bmAc9 = pd.read_csv('data/R090/bmAc.csv', names=['bm'])
bminAc9 = pd.read_csv('data/R090/bminAc.csv', names=['bm'])
#
conf92 = pd.read_csv('data/R092/Conformation_A001.txt', names=['time','x','y','z'], delim_whitespace=True)
bmAc92 = pd.read_csv('data/R092/bmAc.csv', names=['bm'])
bminAc92 = pd.read_csv('data/R092/bminAc.csv', names=['bm'])
#
conf94 = pd.read_csv('data/R094/Conformation_A001.txt', names=['time','x','y','z'], delim_whitespace=True)
bmAc94 = pd.read_csv('data/R094/bmAc.csv', names=['bm'])
bminAc94 = pd.read_csv('data/R094/bminAc.csv', names=['bm'])
#defF = 9.2 pN, actF = 9.2 pN, R = 0.92, B = 13, ATP = 2000, MD = 3000, S = 77, T = 5
confb = pd.read_csv('data/b/Conformation_A001.txt', names=['time','x','y','z'], delim_whitespace=True)
bmAcb = pd.read_csv('data/b/bmAc.csv', names=['bm'])
bminAcb = pd.read_csv('data/b/bminAc.csv', names=['bm'])
#defF = 9.2 pN, actF = 9.2 pN, R = 0.92, B = 2, ATP = 2000, MD = 2000, S = 273, T = 5
confb2 = pd.read_csv('data/2bds/Conformation_A001.txt', names=['time','x','y','z'], delim_whitespace=True)
bmAcb2 = pd.read_csv('data/2bds/bmAc.csv', names=['bm'])
bminAcb2 = pd.read_csv('data/2bds/bminAc.csv', names=['bm'])

# %%
Head = conf.iloc[0::beads,:]
Head = Head.reset_index(drop=True)
Head01 = Head.iloc[0::10,:]
Head01 = Head01.reset_index(drop=True)

dxHead = np.diff(Head['x'])
dyHead = np.diff(Head['y'])
dxHead01 = np.diff(Head01['x'])
dyHead01 = np.diff(Head01['y'])

distHead = np.sqrt((dxHead**2)+(dyHead**2))
spdHead = distHead/(1*dt)
avSpdHead = np.mean(spdHead)
distHead01 = np.sqrt((dxHead01**2)+(dyHead01**2))
spdHead01 = distHead01/(10*dt)
avSpdHead01 = np.mean(spdHead01)

stdHead = np.sum(((spdHead-avSpdHead)**2)/(np.size(spdHead)-1))
stdHead = np.sqrt(stdHead)
stdHead01 = np.sum(((spdHead01-avSpdHead01)**2)/(np.size(spdHead01)-1))
stdHead01 = np.sqrt(stdHead01)

xHead = np.arange(0,spdHead.shape[0])
xHead01 = np.arange(0,spdHead.shape[0], step=10)

#xHead = np.linspace(0,spdHead.shape[0],spdHead.shape[0])
#xHead01 = np.linspace(0,spdHead.shape[0],spdHead.shape[0])

Tail = conf.iloc[(beads-1)::beads,:]
Tail = Tail.reset_index(drop=True)
Tail01 = Tail.iloc[0::10,:]
Tail01 = Tail01.reset_index(drop=True)

dxTail = np.diff(Tail['x'])
dyTail = np.diff(Tail['y'])
dxTail01 = np.diff(Tail01['x'])
dyTail01 = np.diff(Tail01['y'])

distTail = np.sqrt((dxTail**2)+(dyTail**2))
spdTail = distTail/(1*dt)
avSpdTail = np.mean(spdTail)
distTail01 = np.sqrt((dxTail01**2)+(dyTail01**2))
spdTail01 = distTail01/(10*dt)
avSpdTail01 = np.mean(spdTail01)

stdTail = np.sum(((spdTail-avSpdTail)**2)/(np.size(spdTail)-1))
stdTail = np.sqrt(stdTail)
stdTail01 = np.sum(((spdTail01-avSpdTail01)**2)/(np.size(spdTail01)-1))
stdTail01 = np.sqrt(stdTail01)

xTail = np.arange(0,spdTail.shape[0])
xTail01 = np.arange(0,spdTail.shape[0], step=10)




Head92 = conf92.iloc[0::beads,:]
Head92 = Head92.reset_index(drop=True)

dxHead92 = np.diff(Head92['x'])
dyHead92 = np.diff(Head92['y'])

distHead92 = np.sqrt((dxHead92**2)+(dyHead92**2))
spdHead92 = distHead92/(1*dt)
avSpdHead92 = np.mean(spdHead92)


Head94 = conf94.iloc[0::beads,:]
Head94 = Head94.reset_index(drop=True)

dxHead94 = np.diff(Head94['x'])
dyHead94 = np.diff(Head94['y'])

distHead94 = np.sqrt((dxHead94**2)+(dyHead94**2))
spdHead94 = distHead94/(1*dt)
avSpdHead94 = np.mean(spdHead94)




Head9 = conf9.iloc[0::beads,:]
Head9 = Head9.reset_index(drop=True)

dxHead9 = np.diff(Head9['x'])
dyHead9 = np.diff(Head9['y'])

distHead9 = np.sqrt((dxHead9**2)+(dyHead9**2))
spdHead9 = distHead9/(1*dt)
avSpdHead9 = np.mean(spdHead9)

stdHead = np.sum(((spdHead-avSpdHead)**2)/(np.size(spdHead)-1))
stdHead = np.sqrt(stdHead)
stdHead01 = np.sum(((spdHead01-avSpdHead01)**2)/(np.size(spdHead01)-1))
stdHead01 = np.sqrt(stdHead01)



Head01_9 = Head9.iloc[0::10,:]
Head01_9 = Head01_9.reset_index(drop=True)

dxHead01_9 = np.diff(Head01_9['x'])
dyHead01_9 = np.diff(Head01_9['y'])

distHead01_9 = np.sqrt((dxHead01_9**2)+(dyHead01_9**2))
spdHead01_9 = distHead01_9/(10*dt)
avSpdHead01_9 = np.mean(spdHead01_9)

Head01_92 = Head92.iloc[0::10,:]
Head01_92 = Head01_92.reset_index(drop=True)

dxHead01_92 = np.diff(Head01_92['x'])
dyHead01_92 = np.diff(Head01_92['y'])

distHead01_92 = np.sqrt((dxHead01_92**2)+(dyHead01_92**2))
spdHead01_92 = distHead01_92/(10*dt)
avSpdHead01_92 = np.mean(spdHead01_92)

Head01_94 = Head94.iloc[0::10,:]
Head01_94 = Head01_94.reset_index(drop=True)

dxHead01_94 = np.diff(Head01_94['x'])
dyHead01_94 = np.diff(Head01_94['y'])

distHead01_94 = np.sqrt((dxHead01_94**2)+(dyHead01_94**2))
spdHead01_94 = distHead01_94/(10*dt)
avSpdHead01_94 = np.mean(spdHead01_94)


Headb = confb.iloc[0::beads,:]
Headb = Headb.reset_index(drop=True)

dxHeadb = np.diff(Headb['x'])
dyHeadb = np.diff(Headb['y'])

distHeadb = np.sqrt((dxHeadb**2)+(dyHeadb**2))
spdHeadb = distHeadb/(1*dt)
avSpdHeadb = np.mean(spdHeadb)



Headb2 = confb2.iloc[0::beads2,:]
Headb2 = Headb2.reset_index(drop=True)

dxHeadb2 = np.diff(Headb2['x'])
dyHeadb2 = np.diff(Headb2['y'])

distHeadb2 = np.sqrt((dxHeadb2**2)+(dyHeadb2**2))
spdHeadb2 = distHeadb2/(1*dt)
avSpdHeadb2 = np.mean(spdHeadb2)

# %%
s = spdHead
s = np.insert(s,0,0)
s = pd.DataFrame(s)

alld = pd.concat([s,bmAc,bminAc], axis=1)
alld.columns=['spd','act','def']
rto = alld['act']/(alld['act']+alld['def'])
alld = pd.concat([s,bmAc,bminAc,rto], axis=1)
alld.columns=['spd','act','def','rto']

s9 = spdHead9
s9 = np.insert(s9,0,0)
s9 = pd.DataFrame(s9)
alld9 = pd.concat([s9,bmAc9,bminAc9], axis=1)
alld9.columns=['spd','act','def']
rto9 = alld9['act']/(alld9['act']+alld9['def'])
alld9 = pd.concat([s9,bmAc9,bminAc9,rto9], axis=1)
alld9.columns=['spd','act','def','rto']

s92 = spdHead92
s92 = np.insert(s92,0,0)
s92 = pd.DataFrame(s92)
alld92 = pd.concat([s92,bmAc92,bminAc92], axis=1)
alld92.columns=['spd','act','def']
rto92 = alld92['act']/(alld92['act']+alld92['def'])
alld92 = pd.concat([s92,bmAc92,bminAc92,rto92], axis=1)
alld92.columns=['spd','act','def','rto']

s94 = spdHead94
s94 = np.insert(s94,0,0)
s94 = pd.DataFrame(s94)
alld94 = pd.concat([s94,bmAc94,bminAc94], axis=1)
alld94.columns=['spd','act','def']
rto94 = alld94['act']/(alld94['act']+alld94['def'])
alld94 = pd.concat([s94,bmAc94,bminAc94,rto94], axis=1)
alld94.columns=['spd','act','def','rto']

sb = spdHeadb
sb = np.insert(sb,0,0)
sb = pd.DataFrame(sb)
alldb = pd.concat([sb,bmAcb,bminAcb], axis=1)
alldb.columns=['spd','act','def']

sb2 = spdHeadb2
sb2 = np.insert(sb2,0,0)
sb2 = pd.DataFrame(sb2)
alldb2 = pd.concat([sb2,bmAcb2,bminAcb2], axis=1)
alldb2.columns=['spd','act','def']

# %%
s01 = spdHead01
s01 = np.insert(s01,0,0)
#s01 = pd.DataFrame(s01)
x01 = np.linspace(0,5,51)

s01_9 = spdHead01_9
s01_9 = np.insert(s01_9,0,0)
x01_9 = np.linspace(0,5,51)

s01_92 = spdHead01_92
s01_92 = np.insert(s01_92,0,0)
x01_92 = np.linspace(0,5,51)

s01_94 = spdHead01_94
s01_94 = np.insert(s01_94,0,0)
x01_94 = np.linspace(0,5,51)

# %%
s01 = spdHead01
s01 = np.insert(s01,0,0)
s01 = pd.DataFrame(s01)

s01_9 = spdHead01_9
s01_9 = np.insert(s01_9,0,0)
s01_9 = pd.DataFrame(s01_9)

s01_92 = spdHead01_92
s01_92 = np.insert(s01_92,0,0)
s01_92 = pd.DataFrame(s01_92)

s01_94 = spdHead01_94
s01_94 = np.insert(s01_94,0,0)
s01_94 = pd.DataFrame(s01_94)

bmAc_ = bmAc[0::10].reset_index(drop=True)
bminAc_ = bminAc[0::10].reset_index(drop=True)
rto_ = rto[0::10].reset_index(drop=True)

bmAc9_9 = bmAc9[0::10].reset_index(drop=True)
bminAc9_9 = bminAc9[0::10].reset_index(drop=True)
rto9_9 = rto9[0::10].reset_index(drop=True)

bmAc9_92 = bmAc92[0::10].reset_index(drop=True)
bminAc9_92 = bminAc92[0::10].reset_index(drop=True)
rto9_92 = rto92[0::10].reset_index(drop=True)

bmAc9_94 = bmAc94[0::10].reset_index(drop=True)
bminAc9_94 = bminAc94[0::10].reset_index(drop=True)
rto9_94 = rto94[0::10].reset_index(drop=True)

alld01 = pd.concat([s01,bmAc_,bminAc_,rto_], axis=1)
alld01.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']

alld01_9 = pd.concat([s01_9,bmAc9_9,bminAc9_9,rto9_9], axis=1)
alld01_9.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']

alld01_92 = pd.concat([s01_92,bmAc9_92,bminAc9_92,rto9_92], axis=1)
alld01_92.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']

alld01_94 = pd.concat([s01_94,bmAc9_94,bminAc9_94,rto9_94], axis=1)
alld01_94.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']

# %%
cm = 1/2.54
plt.figure(figsize=(15*cm,10*cm))
plt.scatter(alld9['rto'],alld9['spd'], s=1, marker='.', facecolor='None', color='red', label='R = 0.90')
plt.scatter(alld92['rto'],alld92['spd'],s=1, marker='.', facecolor='None', color='green', label='R = 0.92')
plt.scatter(alld94['rto'],alld94['spd'],s=1, marker='.', facecolor='None', color='blue', label='R = 0.94')
plt.xlabel('Binding active ratio')
plt.ylabel('Speed')
plt.legend()
#plt.savefig('fig/speed_bindingR.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
cm = 1/2.54
fig, ax = plt.subplots(1,1, figsize=(15*cm,10*cm))
corr = alld01_9['actRATIO'].corr(alld01_9['SPEED'])
ax.scatter(alld01_9['actRATIO'],alld01_9['SPEED'], s=7, marker='.', facecolor='None', color='brown', label='R = 0.90, corr = %s'%round(corr,5))
corr = alld01_92['actRATIO'].corr(alld01_92['SPEED'])
ax.scatter(alld01_92['actRATIO'],alld01_92['SPEED'],s=7, marker='.', facecolor='None', color='lime', label='R = 0.92, corr = %s'%round(corr,5))
corr = alld01_94['actRATIO'].corr(alld01_94['SPEED'])
ax.scatter(alld01_94['actRATIO'],alld01_94['SPEED'],s=7, marker='.', facecolor='None', color='blue', label='R = 0.94, corr = %s'%round(corr,5))
ax.set_xlabel('Binding active ratio')
ax.set_ylabel('Speed')
#ax.set_xticks(np.arange(0,1,0.1))
#ax.set_yticks(np.arange(0,7,1))
ax.minorticks_on()
ax.tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax.tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)
ax.legend()
#plt.savefig('fig/speed_bindingRt0.1.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
fig, ax = plt.subplots(4,2,figsize=(18,10))
x = np.linspace(0,5,501)

ax[0,0].plot(x,alld['spd'], markerfacecolor='None', lw=1,color='red')
ax[0,0].plot(x01,s01, marker='o',markerfacecolor='None', lw=1, color='gray')
ax[0,0].set_ylabel('Speed ($\mu m$)', fontsize=16)
ax[0,0].set_title('defF = 4.6 pN, R = 0.5', fontsize=16)
ax[0,0].minorticks_on()
ax[0,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[0,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

ax[1,0].plot(x,alld['act'], markerfacecolor='None', lw=1,color='green')
ax[1,0].plot(x[0::10],alld['act'][0::10], marker='o',markerfacecolor='None', lw=1,color='gray')
ax[1,0].set_ylabel('Binding active', fontsize=16)
ax[1,0].minorticks_on()
ax[1,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[1,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

ax[2,0].plot(x,alld['def'], markerfacecolor='None', lw=1,color='blue')
ax[2,0].plot(x[0::10],alld['def'][0::10], marker='o',markerfacecolor='None', lw=1,color='gray')
ax[2,0].set_ylabel('Binding defective', fontsize=16)
ax[2,0].minorticks_on()
ax[2,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[2,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

ax[3,0].plot(x,rto, markerfacecolor='None', lw=1,color='lime')
ax[3,0].plot(x[0::10],rto[0::10], marker='o',markerfacecolor='None', lw=1,color='gray')
ax[3,0].set_xlabel('Time (sec.)', fontsize=16)
ax[3,0].set_ylabel('Active ratio', fontsize=16)
ax[3,0].minorticks_on()
ax[3,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[3,0].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)
#==================================================================
ax[0,1].plot(x,alld9['spd'], markerfacecolor='None', lw=1,color='red')
ax[0,1].plot(x01_9,s01_9, marker='o',markerfacecolor='None', lw=1,color='gray')
#ax[0,1].set_title('defF = 9.2 pN, R = 0.92', fontsize=16)
ax[0,1].minorticks_on()
ax[0,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[0,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

ax[1,1].plot(x,alld9['act'],markerfacecolor='None', lw=1, color='green')
ax[1,1].plot(x[0::10],alld9['act'][0::10], marker='o',markerfacecolor='None', lw=1,color='gray')
ax[1,1].minorticks_on()
ax[1,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[1,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

ax[2,1].plot(x,alld9['def'], color='blue')
ax[2,1].plot(x[0::10],alld9['def'][0::10], marker='o',markerfacecolor='None', lw=1,color='gray')
ax[2,1].minorticks_on()
ax[2,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[2,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

ax[3,1].plot(x,rto9, color='lime')
ax[3,1].plot(x[0::10],rto9[0::10], marker='o',markerfacecolor='None', lw=1,color='gray')
ax[3,1].set_xlabel('Time (sec.)', fontsize=16)
ax[3,1].minorticks_on()
ax[3,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax[3,1].tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)

#plt.savefig('fig/speed_binding_corr_F4.6-9.2pN.pdf', format='pdf', dpi=500, bbox_inches='tight')
#plt.close()

# %%
fig, ax = plt.subplots(1,1,figsize=(20,8))
x = np.linspace(0,5,501)

ax.plot(x,alld9['spd'], marker='.',markerfacecolor='None', lw=1, color='red')
ax.plot(x01_9,s01_9, marker='o',markerfacecolor='None', lw=1, color='gray')
#ax.set_title('defF = 9.2 pN, R = 0.92', fontsize=16)
ax.minorticks_on()
ax.tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
ax.tick_params('both',direction='in',top=True,right=True,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)
#plt.savefig('fig/speed_binding_corr_F4.6-9.2pN_big.pdf', format='pdf', dpi=500, bbox_inches='tight')

# %%
import seaborn as sns
import scipy.stats as stats
#sns.set(style='darkgrid', color_codes=True)
sns.set(style='white', color_codes=True)# font_scale=1.2)

# %%
data = alld01_9
x = 'actRATIO' #% -- uncomment for active binding ratio
figName = 'corr090' #%
#x = 'ACTIVE' #bm -- active binding number
#figName = 'corr090bm' #bm
y = 'SPEED'
figLabel = '(a)'
#========================================
g = sns.jointplot(data=data, x=x, y=y, kind='reg', height=10*cm, color='lime', scatter_kws={'s':2})
# , xlim=(0,0.9), ylim=(0,16) #.annotate(stats.pearsonr)
corr = data[x].corr(data[y])
#========================================
g.ax_joint.minorticks_on()
g.ax_joint.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
g.ax_joint.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)
g.ax_joint.set_ylabel('Speed ($\mu m$)', fontsize=14)
#========================================% -- uncomment this for %
# g.ax_joint.set_yticks(np.arange(0,9,2))
# g.ax_joint.set_xticks(np.arange(0.2,1.01,0.2))
# plt.text(0.4,6,'corr = '+str(round(corr,5)), fontsize=14)
# plt.text(0.6,-2.8,figLabel, ha='center', fontsize=14)
# g.ax_joint.set_xlabel('Binding active myosin ($\%$)', fontsize=14)
# g.ax_joint.spines['left'].set_bounds(0,8)
# g.ax_joint.spines['bottom'].set_bounds(0.2,1.0)
#plt.savefig('fig/'+figName, format='pdf', dpi=500, bbox_inches='tight')
#=======================================bm -- uncomment this for bm
g.ax_joint.set_yticks(np.arange(0,9,2))
g.ax_joint.set_xticks(np.arange(10,90,15))
plt.text(25,7,'corr = '+str(round(corr,5)), fontsize=14)
plt.text(47.5,-2.4,figLabel, ha='center', fontsize=14)
g.ax_joint.set_xlabel('Binding active myosin (No.)', fontsize=14)
g.ax_joint.spines['left'].set_bounds(0,8)
g.ax_joint.spines['bottom'].set_bounds(10,85)
#plt.savefig('fig/'+figName, format='pdf', dpi=500, bbox_inches='tight')
#=======================================

plt.show()

# %%
data = alld01_92
x = 'actRATIO' #% -- uncomment for active binding ratio
figName = 'corr090' #%
#x = 'ACTIVE' #bm -- active binding number
#figName = 'corr090bm' #bm
y = 'SPEED'
figLabel = '(b)'
#========================================
g = sns.jointplot(data=data, x=x, y=y, kind='reg', height=10*cm, color='lime', scatter_kws={'s':2})
# , xlim=(0,0.9), ylim=(0,16) #.annotate(stats.pearsonr)
corr = data[x].corr(data[y])
#========================================
g.ax_joint.minorticks_on()
g.ax_joint.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
g.ax_joint.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)
g.ax_joint.set_ylabel('Speed ($\mu m$)', fontsize=14)
#========================================% -- uncomment this for %
# g.ax_joint.set_yticks(np.arange(0,9,2))
# g.ax_joint.set_xticks(np.arange(0.2,1.01,0.2))
# plt.text(0.4,6,'corr = '+str(round(corr,5)), fontsize=14)
# plt.text(0.6,-2.8,figLabel, ha='center', fontsize=14)
# g.ax_joint.set_xlabel('Binding active myosin ($\%$)', fontsize=14)
# g.ax_joint.spines['left'].set_bounds(0,8)
# g.ax_joint.spines['bottom'].set_bounds(0.2,1.0)
#plt.savefig('fig/'+figName, format='pdf', dpi=500, bbox_inches='tight')
#=======================================bm -- uncomment this for bm
g.ax_joint.set_yticks(np.arange(0,9,2))
g.ax_joint.set_xticks(np.arange(10,90,15))
plt.text(25,7,'corr = '+str(round(corr,5)), fontsize=14)
plt.text(47.5,-2.4,figLabel, ha='center', fontsize=14)
g.ax_joint.set_xlabel('Binding active myosin (No.)', fontsize=14)
g.ax_joint.spines['left'].set_bounds(0,8)
g.ax_joint.spines['bottom'].set_bounds(10,85)
#plt.savefig('fig/'+figName, format='pdf', dpi=500, bbox_inches='tight')
#=======================================

plt.show()

# %%
data = alld01_94
x = 'actRATIO' #% -- uncomment for active binding ratio
figName = 'corr090' #%
#x = 'ACTIVE' #bm -- active binding number
#figName = 'corr090bm' #bm
y = 'SPEED'
figLabel = '(c)'
#========================================
g = sns.jointplot(data=data, x=x, y=y, kind='reg', height=10*cm, color='lime', scatter_kws={'s':2})
# , xlim=(0,0.9), ylim=(0,16) #.annotate(stats.pearsonr)
corr = data[x].corr(data[y])
#========================================
g.ax_joint.minorticks_on()
g.ax_joint.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=8, width=0.5,which='major', labelsize=14)
g.ax_joint.tick_params('both',direction='in',top=False,right=False,bottom=True,left=True,length=4, width=0.4,which='minor', labelsize=14)
g.ax_joint.set_ylabel('Speed ($\mu m$)', fontsize=14)
#========================================% -- uncomment this for %
# g.ax_joint.set_yticks(np.arange(0,9,2))
# g.ax_joint.set_xticks(np.arange(0.2,1.01,0.2))
# plt.text(0.4,6,'corr = '+str(round(corr,5)), fontsize=14)
# plt.text(0.6,-2.8,figLabel, ha='center', fontsize=14)
# g.ax_joint.set_xlabel('Binding active myosin ($\%$)', fontsize=14)
# g.ax_joint.spines['left'].set_bounds(0,8)
# g.ax_joint.spines['bottom'].set_bounds(0.2,1.0)
#plt.savefig('fig/'+figName, format='pdf', dpi=500, bbox_inches='tight')
#=======================================bm -- uncomment this for bm
g.ax_joint.set_yticks(np.arange(0,9,2))
g.ax_joint.set_xticks(np.arange(10,90,15))
plt.text(25,7,'corr = '+str(round(corr,5)), fontsize=14)
plt.text(47.5,-2.4,figLabel, ha='center', fontsize=14)
g.ax_joint.set_xlabel('Binding active myosin (No.)', fontsize=14)
g.ax_joint.spines['left'].set_bounds(0,8)
g.ax_joint.spines['bottom'].set_bounds(10,85)
#plt.savefig('fig/'+figName, format='pdf', dpi=500, bbox_inches='tight')
#=======================================

plt.show()

# %%
# !pdfjam --nup 3x1 fig/corr090.pdf fig/corr092.pdf fig/corr094.pdf --outfile fig/corr090-094.pdf
#!pdfjam --nup 3x1 fig/corr090bm.pdf fig/corr092bm.pdf fig/corr094bm.pdf --outfile fig/corr090-094bm.pdf
# Out:
#           ----
#   pdfjam: This is pdfjam version 2.08.
#   pdfjam: Reading any site-wide or user-specific defaults...
#           (none found)
#   pdfjam: Effective call for this run of pdfjam:
#           /usr/bin/pdfjam --nup '3x1' --outfile fig/corr090-094bm.pdf -- fig/corr090bm.pdf - fig/corr092bm.pdf - fig/corr094bm.pdf -
#   pdfjam: Calling pdflatex...
#   pdfjam: Finished.  Output was to 'fig/corr090-094bm.pdf'.

# %%
fig, ax = plt.subplots(3,2,figsize=(18,8))
x = np.linspace(0,5,501)

ax[0,0].plot(x,alld['spd'], color='red')
ax[0,0].set_ylabel('Speed ($\mu m$)', fontsize=16)
ax[0,0].set_title('defF = 4.6 pN, R = 0.5', fontsize=16)
ax[0,0].minorticks_on()
ax[0,0].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[0,0].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[1,0].plot(x,alld['act'].T, color='green')
ax[1,0].set_ylabel('Binding active', fontsize=16)
ax[1,0].minorticks_on()
ax[1,0].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[1,0].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[2,0].plot(x,alld['def'].T, color='blue')
ax[2,0].set_ylabel('Binding defective', fontsize=16)
ax[2,0].set_xlabel('Time (sec.)', fontsize=16)
ax[2,0].minorticks_on()
ax[2,0].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[2,0].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)
#==================================================================
ax[0,1].plot(x,alldb['spd'], color='red')
ax[0,1].set_title('defF = 9.2 pN, R = 0.92, Bunble', fontsize=16)
ax[0,1].minorticks_on()
ax[0,1].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[0,1].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[1,1].plot(x,alldb['act'].T, color='green')
ax[1,1].minorticks_on()
ax[1,1].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[1,1].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[2,1].plot(x,alldb['def'].T, color='blue')
ax[2,1].set_xlabel('Time (sec.)', fontsize=16)
ax[2,1].minorticks_on()
ax[2,1].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[2,1].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

#plt.savefig('fig/speed_binding_corr_F4.6-9.2pN_Bdl.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.close()

# %%
fig, ax = plt.subplots(3,2,figsize=(18,8))
x = np.linspace(0,5,501)

ax[0,0].plot(x,alld['spd'], color='red')
ax[0,0].set_ylabel('Speed ($\mu m$)', fontsize=16)
ax[0,0].set_title('defF = 4.6 pN, R = 0.5', fontsize=16)
ax[0,0].minorticks_on()
ax[0,0].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[0,0].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[1,0].plot(x,alld['act'].T, color='green')
ax[1,0].set_ylabel('Binding active', fontsize=16)
ax[1,0].minorticks_on()
ax[1,0].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[1,0].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[2,0].plot(x,alld['def'].T, color='blue')
ax[2,0].set_ylabel('Binding defective', fontsize=16)
ax[2,0].set_xlabel('Time (sec.)', fontsize=16)
ax[2,0].minorticks_on()
ax[2,0].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[2,0].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)
#==================================================================
ax[0,1].plot(x,alldb2['spd'], color='red')
ax[0,1].set_title('defF = 9.2 pN, R = 0.92, 2Beads AF', fontsize=16)
ax[0,1].minorticks_on()
ax[0,1].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[0,1].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[1,1].plot(x,alldb2['act'].T, color='green')
ax[1,1].minorticks_on()
ax[1,1].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[1,1].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

ax[2,1].plot(x,alldb2['def'].T, color='blue')
ax[2,1].set_xlabel('Time (sec.)', fontsize=16)
ax[2,1].minorticks_on()
ax[2,1].tick_params('both',direction='in',top=True,right=True,length=8, width=0.5,which='major', labelsize=14)
ax[2,1].tick_params('both',direction='in',top=True,right=True,length=4, width=0.4,which='minor', labelsize=14)

#plt.savefig('fig/speed_binding_corr_F4.6-9.2pN_2B.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.close()

# %%
alld.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']
sns.jointplot(data=alld, x='ACTIVE', y='DEFECTIVE', xlim=(-0,60), ylim=(-0,160), kind='reg', height=5, color='orange')
#sns.
r = alld['ACTIVE'].corr(alld['DEFECTIVE'])
plt.text(5,140,'corr = '+str(round(r,5)), fontsize=13)
plt.text(30,200,'defF = 4.6 pN, R = 0.50, B = 13, MD = 3000', ha='center', fontsize= 16)
#plt.suptitle('defF = 4.6 pN, R = 0.5, B = 13, MD = 3000')
#plt.savefig('fig/act_def_corr_R0.5_F4.6pN.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
alld9.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']
sns.jointplot(data=alld9, x='ACTIVE', y='DEFECTIVE', xlim=(-0,80), ylim=(-0,50), kind='reg', height=5, color='orange')#.annotate(stats.pearsonr)
r = alld9['ACTIVE'].corr(alld9['DEFECTIVE'])
plt.text(10,40,'corr = '+str(round(r,5)), fontsize=13)
plt.text(40,61,'defF = 9.2 pN, R = 0.92, B = 13, MD = 3000', ha='center', fontsize= 16)
#plt.savefig('fig/act_def_corr_R0.92_F9.2pN.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
#!pdfjam --nup 2x1 fig/act_def_corr_R0.5_F4.6pN.pdf fig/act_def_corr_R0.92_F9.2pN.pdf --outfile fig/corr_4.6-9.2pN.pdf

# %%
alld.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']
sns.jointplot(data=alld, x='actRATIO', y='SPEED', xlim=(0,1.0), ylim=(0,50), kind='reg', height=5, color='orange', scatter_kws={'s':2})#.annotate(stats.pearsonr)
r = alld['actRATIO'].corr(alld['SPEED'])
plt.text(0.3,40,'corr = '+str(round(r,5)), fontsize=13)
#plt.text(0.5,63,'defF = 4.6 pN, R = 0.50, B = 13, MD = 3000', ha='center', fontsize= 16)
#plt.savefig('fig/act_def_corr_R0.5_F4.6pN_spd.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
# !pdfjam --nup 2x1 fig/act_def_corr_R0.5_F4.6pN_spd.pdf fig/act_def_corr_R0.92_F9.2pN_spd.pdf --outfile fig/corr_4.6-9.2pN_spd.pdf
# Out:
#           ----
#   pdfjam: This is pdfjam version 2.08.
#   pdfjam: Reading any site-wide or user-specific defaults...
#           (none found)
#   pdfjam: Effective call for this run of pdfjam:
#           /usr/bin/pdfjam --nup '2x1' --outfile fig/corr_4.6-9.2pN_spd.pdf -- fig/act_def_corr_R0.5_F4.6pN_spd.pdf - fig/act_def_corr_R0.92_F9.2pN_spd.pdf -
#   pdfjam: Calling pdflatex...
#   pdfjam: Finished.  Output was to 'fig/corr_4.6-9.2pN_spd.pdf'.

# %%
alld.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']
sns.jointplot(data=alld, x='ACTIVE', y='SPEED', xlim=(0,53), ylim=(0,53), kind='reg', height=5, color='orange')#.annotate(stats.pearsonr)
r = alld['ACTIVE'].corr(alld['SPEED'])
plt.text(10,40,'corr = '+str(round(r,5)), fontsize=13)
plt.text(26,65,'defF = 4.6 pN, R = 0.50, B = 13, MD = 3000', ha='center', fontsize= 16)
plt.savefig('fig/act_def_corr_R0.5_F4.6pN_act_spd.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
alld9.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']
sns.jointplot(data=alld9, x='ACTIVE', y='SPEED', xlim=(0,80), ylim=(0,16), kind='reg', height=5, color='orange')#.annotate(stats.pearsonr)
r = alld9['ACTIVE'].corr(alld9['SPEED'])
plt.text(30,12.5,'corr = '+str(round(r,5)), fontsize=13)
plt.text(40,20,'defF = 9.2 pN, R = 0.92, B = 13, MD = 3000', ha='center', fontsize= 16)
plt.savefig('fig/act_def_corr_R0.92_F9.2pN_act_spd.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
# !pdfjam --nup 2x1 fig/act_def_corr_R0.5_F4.6pN_act_spd.pdf fig/act_def_corr_R0.92_F9.2pN_act_spd.pdf --outfile fig/corr_4.6-9.2pN_act_spd.pdf
# Out:
#           ----
#   pdfjam: This is pdfjam version 2.08.
#   pdfjam: Reading any site-wide or user-specific defaults...
#           (none found)
#   pdfjam: Effective call for this run of pdfjam:
#           /usr/bin/pdfjam --nup '2x1' --outfile fig/corr_4.6-9.2pN_act_spd.pdf -- fig/act_def_corr_R0.5_F4.6pN_act_spd.pdf - fig/act_def_corr_R0.92_F9.2pN_act_spd.pdf -
#   pdfjam: Calling pdflatex...
#   pdfjam: Finished.  Output was to 'fig/corr_4.6-9.2pN_act_spd.pdf'.

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
sns.heatmap(alld.corr(method='pearson'),annot=True, fmt='.5f', cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax[0])
sns.heatmap(alld9.corr(method='pearson'),annot=True, fmt='.5f', cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax[1])
#ax[0].set_yticklabels(ax[0].get_yticklabels(), rotation='vertical')
ax[0].set_title('ts = 0.01 | defF = 4.6 pN, R = 0.50, B = 13, MD = 3000')
ax[1].set_title('ts = 0.01 | defF = 9.2 pN, R = 0.92, B = 13, MD = 3000')
#plt.savefig('fig/act_def_corr_all.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
alld01.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']
sns.jointplot(data=alld01, x='actRATIO', y='SPEED', xlim=(0,0.9), ylim=(0,5.5), kind='reg', height=5, color='orange', scatter_kws={'s':2})#.annotate(stats.pearsonr)
r = alld01['actRATIO'].corr(alld01['SPEED'])
plt.text(0.3,5,'corr = '+str(round(r,5)), fontsize=13)
#plt.text(0.5,63,'defF = 4.6 pN, R = 0.50, B = 13, MD = 3000', ha='center', fontsize= 16)
#plt.savefig('fig/act_def_corr_R0.5_F4.6pN_act_spd01.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
alld01_9.columns=['SPEED','ACTIVE','DEFECTIVE','actRATIO']
sns.jointplot(data=alld01_9, x='actRATIO', y='SPEED', xlim=(0,1.0), ylim=(0,7), kind='reg', height=5, color='orange', scatter_kws={'s':2})#.annotate(stats.pearsonr)
r = alld01_9['actRATIO'].corr(alld01_9['SPEED'])
plt.text(0.2,5.0,'corr = '+str(round(r,5)), fontsize=13)
#plt.text(0.5,63,'defF = 4.6 pN, R = 0.50, B = 13, MD = 3000', ha='center', fontsize= 16)
#plt.savefig('fig/act_def_corr_R0.92_F9.2pN_act_spd01.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %%
# !pdfjam --nup 2x1 fig/act_def_corr_R0.92_F9.2pN_spd.pdf fig/act_def_corr_R0.92_F9.2pN_act_spd01.pdf --outfile fig/corr_4.6-9.2pN_act_spd01.pdf
# Out:
#           ----
#   pdfjam: This is pdfjam version 2.08.
#   pdfjam: Reading any site-wide or user-specific defaults...
#           (none found)
#   pdfjam: Effective call for this run of pdfjam:
#           /usr/bin/pdfjam --nup '2x1' --outfile fig/corr_4.6-9.2pN_act_spd01.pdf -- fig/act_def_corr_R0.92_F9.2pN_spd.pdf - fig/act_def_corr_R0.92_F9.2pN_act_spd01.pdf -
#   pdfjam: Calling pdflatex...
#   pdfjam: Finished.  Output was to 'fig/corr_4.6-9.2pN_act_spd01.pdf'.

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
sns.heatmap(alld01.corr(method='pearson'),annot=True, fmt='.5f', cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax[0])
sns.heatmap(alld01_9.corr(method='pearson'),annot=True, fmt='.5f', cmap=plt.get_cmap('coolwarm'), cbar=False, ax=ax[1])
#ax[0].set_yticklabels(ax[0].get_yticklabels(), rotation='vertical')
ax[0].set_title('ts = 0.1 | defF = 4.6 pN, R = 0.50, B = 13, MD = 3000')
ax[1].set_title('ts = 0.1 | defF = 9.2 pN, R = 0.92, B = 13, MD = 3000')
#plt.savefig('fig/act_def_corr_0.1.pdf', format='pdf', dpi=500, bbox_inches='tight')
plt.show()

# %% [markdown]
# #### defF = 4.6 pN, R = 0.5, B = 13, MD = 3000

# %%
corr = alld.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_7e4eb66e_7dad_11eb_9676_650ad83c218drow0_col0,#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow1_col1,#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow0_col1,#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow0_col2,#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow2_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow1_col0{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow1_col2,#T_7e4eb66e_7dad_11eb_9676_650ad83c218drow2_col1{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# #### defF = 9.2 pN, R = 0.92, B = 13, MD = 3000

# %%
corr = alld9.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8574a890_7dad_11eb_9676_650ad83c218drow0_col0,#T_8574a890_7dad_11eb_9676_650ad83c218drow1_col1,#T_8574a890_7dad_11eb_9676_650ad83c218drow2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8574a890_7dad_11eb_9676_650ad83c218drow0_col1,#T_8574a890_7dad_11eb_9676_650ad83c218drow0_col2,#T_8574a890_7dad_11eb_9676_650ad83c218drow2_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8574a890_7dad_11eb_9676_650ad83c218drow1_col0{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_8574a890_7dad_11eb_9676_650ad83c218drow1_col2{
#             background-color:  #e46e56;
#             color:  #000000;
#         }#T_8574a890_7dad_11eb_9676_650ad83c218drow2_col1{
#             background-color:  #e8765c;
#             color:  #000000;
# ...

# %% [markdown]
# #### defF = 9.2 pN, R = 0.92, B = 13, MD = 3000 | Bundle: EI=0.41 NOT 0.073

# %%
corr = alldb.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_8653482a_7dad_11eb_9676_650ad83c218drow0_col0,#T_8653482a_7dad_11eb_9676_650ad83c218drow1_col1,#T_8653482a_7dad_11eb_9676_650ad83c218drow2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_8653482a_7dad_11eb_9676_650ad83c218drow0_col1,#T_8653482a_7dad_11eb_9676_650ad83c218drow0_col2,#T_8653482a_7dad_11eb_9676_650ad83c218drow2_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_8653482a_7dad_11eb_9676_650ad83c218drow1_col0{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_8653482a_7dad_11eb_9676_650ad83c218drow1_col2{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_8653482a_7dad_11eb_9676_650ad83c218drow2_col1{
#             background-color:  #ee8669;
#             color:  #000000;
# ...

# %% [markdown]
# #### defF = 9.2 pN, R = 0.92, B = 2, MD = 2000 | 2Beads AF

# %%
corr = alldb2.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_872e1450_7dad_11eb_9676_650ad83c218drow0_col0,#T_872e1450_7dad_11eb_9676_650ad83c218drow1_col1,#T_872e1450_7dad_11eb_9676_650ad83c218drow2_col2{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_872e1450_7dad_11eb_9676_650ad83c218drow0_col1,#T_872e1450_7dad_11eb_9676_650ad83c218drow0_col2,#T_872e1450_7dad_11eb_9676_650ad83c218drow2_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_872e1450_7dad_11eb_9676_650ad83c218drow1_col0{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_872e1450_7dad_11eb_9676_650ad83c218drow1_col2{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_872e1450_7dad_11eb_9676_650ad83c218drow2_col1{
#             background-color:  #de614d;
#             color:  #000000;
# ...

# %%
# !jupyter nbconvert 05-03-2021_Corr_v11n.ipynb --no-input --to html
# Out:
# [NbConvertApp] Converting notebook 05-03-2021_Corr_v11n.ipynb to html
# [NbConvertApp] Writing 971687 bytes to 05-03-2021_Corr_v11n.html
